# %% [markdown]
# <a href="https://colab.research.google.com/github/SergeiVKalinin/ML-ElectronMicroscopy-2023/blob/main/Lecture%2017/0_rvae_cards.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   This notebook takes you through the application of rotationally invariant variational autoencoder (rVAE) on four different cards datasets and the results analysis.
# *   Each cards dataset if formed by applying a random rotation and shear to the images of the cards. The datasets differ in the limits used for picking the rotations and shear.
# *   rVAE comprises of an additional latent dimension to the regular VAE, which explicitly captures the rotations involved in the image.
# *   This angular latent dimension is unsupervisedly learned while trying to reconstuct the original image.
# *   Like in VAE, this latent dimension is also regularized using a prior.
#
# The rVAEs are defined and trained using a package called Pyroved (https://github.com/ziatdinovmax/pyroVED) which is built on top of Pyro probabilistic programming framework. Please feel free to write to valletisai.mani@gmail.com for further enquiries.

# %%
# Installing Kornia and pyroved
# !pip install -q kornia git+https://github.com/ziatdinovmax/pyroVED@main
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 653.4/653.4 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 732.8/732.8 kB 12.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.9/37.9 MB 12.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for pyroved (setup.py) ... done
#   Building wheel for matplotlib (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mizani 0.8.1 requires matplotlib>=3.5.0, but you have matplotlib 3.3.4 which is incompatible.
# plotnine 0.10.1 requires matplotlib>=3.5.0, but you have matplotlib 3.3.4 which is incompatible.

# %%
# Importing necessary packages

import pyroved as pv
import kornia as K


import cv2
from torchvision.utils import make_grid
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['axes.linewidth'] = 3

tt = torch.tensor

# %%
#@title Helper functions that apply afffine transformations to the dataset
rs = lambda x: cv2.resize(x, (64, 64), cv2.INTER_CUBIC)

def get_data():
    card1 = rs(cv2.imread("cards/card1.JPG", cv2.IMREAD_GRAYSCALE))
    card2 = rs(cv2.imread("cards/card2.JPG", cv2.IMREAD_GRAYSCALE))
    card3 = rs(cv2.imread("cards/card3.JPG", cv2.IMREAD_GRAYSCALE))
    card4 = rs(cv2.imread("cards/card4.JPG", cv2.IMREAD_GRAYSCALE))
    card1 = tt(1 - card1 / card1.max())
    card2 = tt(1 - card2 / card2.max())
    card3 = tt(1 - card3 / card3.max())
    card4 = tt(1 - card4 / card4.max())
    return card1, card2, card3, card4


import math
def transform_imgs(cards, **kwargs):
    np.random.seed(0)
    torch.manual_seed(0)

    a = kwargs.get("angle")
    t = kwargs.get("translation")
    s = (kwargs.get("shear"))
    if s is not None:
        s = math.radians(s)


    n_samples = kwargs.get("samples", 3000)
    n_samples_total = n_samples*4

    card1, card2, card3, card4 = cards[0], cards[1], cards[2], cards[3]

    card1 = card1[None, None].repeat_interleave(n_samples, dim = 0)
    card2 = card2[None, None].repeat_interleave(n_samples, dim = 0)
    card3 = card3[None, None].repeat_interleave(n_samples, dim = 0)
    card4 = card4[None, None].repeat_interleave(n_samples, dim = 0)

    cards_all = torch.cat((card1, card2, card3, card4), dim = 0)

    angles = tt(np.random.uniform(low = -a, high = a, size = [n_samples_total]))
    translations = tt(np.random.uniform(low = -t, high = t, size = [n_samples_total,1])).repeat_interleave(2, dim = 1)
    shears = tt(np.random.uniform(low = -s, high = s, size = [n_samples_total, 1])).repeat_interleave(2, dim = 1)

    transform = nn.Sequential(
        K.augmentation.CenterCrop((48, 48)),
        K.geometry.Affine(angle = angles, translation = translations,
                          shear = shears)
    )

    cards = transform(cards_all).squeeze().float()
    labels = torch.cat([torch.zeros(len(card1)), torch.ones(len(card2)),
                           2*torch.ones(len(card3)), 3*torch.ones(len(card4))])
    return cards, labels, angles, translations, shears


def plot_manifolds(model):
    fig, axes = plt.subplots(2, 2, figsize=(12, 12),
                            subplot_kw={'xticks':[], 'yticks':[]},
                            gridspec_kw=dict(hspace=0.1, wspace=0.05))
    for i, ax in enumerate(axes.flat):
        manifold = model.manifold2d(d=9, label=i, plot=False)
        grid = make_grid(manifold[:, None], nrow=9, pad_value=.5)
        ax.imshow(grid[0], cmap='viridis')
    plt.show()

# %%
# Downloading the cards dataset
# !gdown -q https://drive.google.com/uc?id=1AyGHVflbIjzinkKBURHNVDx1wWg9JixB
# !unzip -o -qq cards.zip

# %% [markdown]
# Here we make 4 different datasets using the above helper functions which are as follows:
# *  cards-i: low rotations (12 degrees) and low shear (1 degree)
# *  cards-ii: low rotations (12 degrees) and high shear (20 degrees)
# *  cards-iii: high rotations (120 degrees) and low shear (1 degree)
# *  cards-iv: high rotations (120 degrees) and high shear (20 degrees)

# %%
# And the ground truth values of the transformations applied to analyze the latent spaces.
cards = get_data()
cards_all1, labels_all1, angles_all1, translations_all1, shears_all1 = transform_imgs(cards, angle = 12, translation = 0.1, shear = 1, samples = 3000)   # cards-i
cards_all2, labels_all2, angles_all2, translations_all2, shears_all2 = transform_imgs(cards, angle = 12, translation = 0.1, shear = 20, samples = 3000)   # cards-ii
cards_all3, labels_all3, angles_all3, translations_all3, shears_all3 = transform_imgs(cards, angle = 120, translation = 0.1, shear = 1, samples = 3000)   # cards-iii
cards_all4, labels_all4, angles_all4, translations_all4, shears_all4 = transform_imgs(cards, angle = 120, translation = 0.1, shear = 20, samples = 3000)   # cards-iv

# %%
# Visualizing the cards before applying transformations
fig, ax = plt.subplots(ncols = 4, figsize = (8,2))
for i in range(4):
    ax[i].imshow(cards[i], cmap = 'gnuplot')
    ax[i].axis('off')

# %% [markdown]
# # Training
# Here we train one model of rVAE per dataset and save the weights.
# These weights will be loaded into the notebook in the next section to avoid the time consuming training process

# %%
# First we initialize the train Loaders for all the datasets

# None corresponds to adding a dummy channel dimension to the dataset
train_loader1 = pv.utils.init_dataloader(cards_all1[:, None], batch_size=50)   #cards-i
train_loader2 = pv.utils.init_dataloader(cards_all2[:, None], batch_size=50)   #cards-ii
train_loader3 = pv.utils.init_dataloader(cards_all3[:, None], batch_size=50)   #cards-iii
train_loader4 = pv.utils.init_dataloader(cards_all4[:, None], batch_size=50)   #cards-iv

# %%
# Training the rVAE on cards-i

in_dim = (48, 48)  # Input dimensions of the dataset i.e., shape of each card's image

# Initialize probabilistic VAE model ->
# (invariances=None: vanilla VAE
#  invariances=['r']: enforces rotational invariance
#  invariances=['t']: enforces translational invariance
#  invariances=['r', 't']: enforces invariance to rotations & translations
#  etc.)


rvae1 = pv.models.iVAE(in_dim, latent_dim=2,  # Number of latent dimensions other than the invariancies
                      hidden_dim_e = [256, 256], # corresponds to the number of neurons in the hidden layers of the encoder
                     hidden_dim_d = [256, 256],  # corresponds to the number of neurons in the hidden layers of the decoder
                     invariances=['r'], seed=0)

# Initialize SVI trainer
trainer1 = pv.trainers.SVItrainer(rvae1)
# Train for n epochs:
for e in range(100):
    trainer1.step(train_loader1)
    trainer1.print_statistics()

# Saving the weights of the trained rVAE model on cards-i
#rvae1.save_weights('/content/drive/MyDrive/VAE Review/rvae_files/rave1')
# Out:
# Epoch: 1 Training loss: 625.2074
# Epoch: 2 Training loss: 322.3593
# Epoch: 3 Training loss: 261.3157
# Epoch: 4 Training loss: 228.3388
# Epoch: 5 Training loss: 203.8007
# Epoch: 6 Training loss: 181.7017
# Epoch: 7 Training loss: 167.0831
# Epoch: 8 Training loss: 142.8089
# Epoch: 9 Training loss: 129.1209
# Epoch: 10 Training loss: 121.3809
# Epoch: 11 Training loss: 115.7217
# Epoch: 12 Training loss: 110.4057
# Epoch: 13 Training loss: 108.8175
# Epoch: 14 Training loss: 106.1817
# Epoch: 15 Training loss: 102.6616
# Epoch: 16 Training loss: 101.1333
# Epoch: 17 Training loss: 98.4400
# Epoch: 18 Training loss: 98.5929
# Epoch: 19 Training loss: 95.7022
# Epoch: 20 Training loss: 96.2244
# Epoch: 21 Training loss: 94.8101
# Epoch: 22 Training loss: 94.0714
# Epoch: 23 Training loss: 94.6537
# Epoch: 24 Training loss: 93.7197
# Epoch: 25 Training loss: 93.0429
# Epoch: 26 Training loss: 92.7894
# Epoch: 27 Training loss: 92.1737
# Epoch: 28 Training loss: 92.7378
# Epoch: 29 Training loss: 91.9906
# Epoch: 30 Training loss: 91.5280
# Epoch: 31 Training loss: 92.7336
# Epoch: 32 Training loss: 91.0463
# Epoch: 33 Training loss: 90.8895
# Epoch: 34 Training loss: 90.1618
# Epoch: 35 Training loss: 91.0739
# Epoch: 36 Training loss: 90.1937
# Epoch: 37 Training loss: 90.5069
# Epoch: 38 Training loss: 91.1755
# Epoch: 39 Training loss: 88.8028
# Epoch: 40 Training loss: 88.3505
# Epoch: 41 Training loss: 89.3502
# Epoch: 42 Training loss: 87.9461
# Epoch: 43 Training loss: 88.8890
# Epoch: 44 Training loss: 88.1732
# Epoch: 45 Training loss: 88.1316
# Epoch: 46 Training loss: 87.0508
# Epoch: 47 Training loss: 86.9508
# Epoch: 48 Training loss: 88.2560
# Epoch: 49 Training loss: 87.7268
# Epoch: 50 Training loss: 86.1563
# Epoch: 51 Training loss: 85.9934
# Epoch: 52 Training loss: 86.5318
# Epoch: 53 Training loss: 86.8404
# Epoch: 54 Training loss: 86.1309
# Epoch: 55 Training loss: 85.5050
# Epoch: 56 Training loss: 85.2096
# Epoch: 57 Training loss: 85.7820
# Epoch: 58 Training loss: 85.5318
# Epoch: 59 Training loss: 84.4155
# Epoch: 60 Training loss: 86.1902
# Epoch: 61 Training loss: 84.3957
# Epoch: 62 Training loss: 85.0282
# Epoch: 63 Training loss: 84.2506
# Epoch: 64 Training loss: 84.8125
# Epoch: 65 Training loss: 84.9029
# Epoch: 66 Training loss: 85.6654
# Epoch: 67 Training loss: 83.8266
# Epoch: 68 Training loss: 83.6460
# Epoch: 69 Training loss: 84.1920
# Epoch: 70 Training loss: 83.4808
# Epoch: 71 Training loss: 84.2824
# Epoch: 72 Training loss: 83.3547
# Epoch: 73 Training loss: 83.5575
# Epoch: 74 Training loss: 83.5944
# Epoch: 75 Training loss: 84.7875
# Epoch: 76 Training loss: 84.3492
# Epoch: 77 Training loss: 83.1398
# Epoch: 78 Training loss: 82.6831
# Epoch: 79 Training loss: 82.6332
# Epoch: 80 Training loss: 83.4165
# Epoch: 81 Training loss: 83.4332
# Epoch: 82 Training loss: 82.9987
# Epoch: 83 Training loss: 83.0226
# Epoch: 84 Training loss: 82.5897
# Epoch: 85 Training loss: 82.7060
# Epoch: 86 Training loss: 82.3716
# Epoch: 87 Training loss: 83.4791
# Epoch: 88 Training loss: 82.4806
# Epoch: 89 Training loss: 82.4339
# Epoch: 90 Training loss: 81.7482
# Epoch: 91 Training loss: 81.9056
# Epoch: 92 Training loss: 82.7979
# Epoch: 93 Training loss: 82.1385
# Epoch: 94 Training loss: 81.8096
# Epoch: 95 Training loss: 82.5473
# Epoch: 96 Training loss: 81.8449
# Epoch: 97 Training loss: 81.8654
# Epoch: 98 Training loss: 82.3862
# Epoch: 99 Training loss: 83.2232
# Epoch: 100 Training loss: 81.3003

# %%
# Training the rVAE on cards-ii

in_dim = (48, 48)  # Input dimensions of the dataset i.e., shape of each card's image

# Initialize probabilistic VAE model ->
# (invariances=None: vanilla VAE
#  invariances=['r']: enforces rotational invariance
#  invariances=['t']: enforces translational invariance
#  invariances=['r', 't']: enforces invariance to rotations & translations
#  etc.)
rvae2 = pv.models.iVAE(in_dim, latent_dim=2, # Number of latent dimensions other than the invariancies
                      hidden_dim_e = [512, 512],   # corresponds to the number of neurons in the hidden layers of the encoder
                     hidden_dim_d = [512, 512],  # corresponds to the number of neurons in the hidden layers of the decoder
                     invariances=['r'], seed=0)

# Initialize SVI trainer
trainer2 = pv.trainers.SVItrainer(rvae2)
# Train for n epochs:
for e in range(100):
    trainer2.step(train_loader2)
    trainer2.print_statistics()

# Saving the weights of the trained rVAE model on cards-ii
#rvae2.save_weights('/content/drive/MyDrive/VAE Review/rvae_files/rave2')
# Out:
# Epoch: 1 Training loss: 646.7456
# Epoch: 2 Training loss: 309.6386
# Epoch: 3 Training loss: 269.0154
# Epoch: 4 Training loss: 232.6189
# Epoch: 5 Training loss: 194.5959
# Epoch: 6 Training loss: 176.6857
# Epoch: 7 Training loss: 171.4734
# Epoch: 8 Training loss: 153.0620
# Epoch: 9 Training loss: 138.9642
# Epoch: 10 Training loss: 131.9284
# Epoch: 11 Training loss: 127.9889
# Epoch: 12 Training loss: 126.4950
# Epoch: 13 Training loss: 124.9888
# Epoch: 14 Training loss: 119.1059
# Epoch: 15 Training loss: 117.1842
# Epoch: 16 Training loss: 119.2856
# Epoch: 17 Training loss: 111.4082
# Epoch: 18 Training loss: 112.1208
# Epoch: 19 Training loss: 114.4731
# Epoch: 20 Training loss: 111.9682
# Epoch: 21 Training loss: 107.8578
# Epoch: 22 Training loss: 114.1351
# Epoch: 23 Training loss: 109.5837
# Epoch: 24 Training loss: 109.3699
# Epoch: 25 Training loss: 107.2752
# Epoch: 26 Training loss: 110.7423
# Epoch: 27 Training loss: 104.5708
# Epoch: 28 Training loss: 108.7596
# Epoch: 29 Training loss: 109.4679
# Epoch: 30 Training loss: 107.8115
# Epoch: 31 Training loss: 106.5999
# Epoch: 32 Training loss: 105.7906
# Epoch: 33 Training loss: 109.5461
# Epoch: 34 Training loss: 105.4505
# Epoch: 35 Training loss: 103.4486
# Epoch: 36 Training loss: 106.3710
# Epoch: 37 Training loss: 106.0498
# Epoch: 38 Training loss: 112.2715
# Epoch: 39 Training loss: 106.0325
# Epoch: 40 Training loss: 102.8306
# Epoch: 41 Training loss: 102.8975
# Epoch: 42 Training loss: 101.8720
# Epoch: 43 Training loss: 103.1421
# Epoch: 44 Training loss: 102.4239
# Epoch: 45 Training loss: 104.8484
# Epoch: 46 Training loss: 109.1064
# Epoch: 47 Training loss: 99.7382
# Epoch: 48 Training loss: 101.2324
# Epoch: 49 Training loss: 105.6262
# Epoch: 50 Training loss: 101.5330
# Epoch: 51 Training loss: 101.7428
# Epoch: 52 Training loss: 101.5236
# Epoch: 53 Training loss: 101.7007
# Epoch: 54 Training loss: 102.3483
# Epoch: 55 Training loss: 106.0104
# Epoch: 56 Training loss: 99.0485
# Epoch: 57 Training loss: 102.9895
# Epoch: 58 Training loss: 102.9094
# Epoch: 59 Training loss: 101.5209
# Epoch: 60 Training loss: 100.0755
# Epoch: 61 Training loss: 102.9742
# Epoch: 62 Training loss: 102.6732
# Epoch: 63 Training loss: 99.1850
# Epoch: 64 Training loss: 98.1167
# Epoch: 65 Training loss: 99.9955
# Epoch: 66 Training loss: 98.8555
# Epoch: 67 Training loss: 98.9337
# Epoch: 68 Training loss: 104.9972
# Epoch: 69 Training loss: 101.2366
# Epoch: 70 Training loss: 100.5331
# Epoch: 71 Training loss: 100.9028
# Epoch: 72 Training loss: 97.7274
# Epoch: 73 Training loss: 98.2212
# Epoch: 74 Training loss: 99.6335
# Epoch: 75 Training loss: 97.6738
# Epoch: 76 Training loss: 99.4982
# Epoch: 77 Training loss: 100.8084
# Epoch: 78 Training loss: 100.6567
# Epoch: 79 Training loss: 98.3518
# Epoch: 80 Training loss: 100.1205
# Epoch: 81 Training loss: 98.6744
# Epoch: 82 Training loss: 100.3755
# Epoch: 83 Training loss: 96.6922
# Epoch: 84 Training loss: 97.8376
# Epoch: 85 Training loss: 98.1765
# Epoch: 86 Training loss: 100.1901
# Epoch: 87 Training loss: 95.9773
# Epoch: 88 Training loss: 98.2909
# Epoch: 89 Training loss: 97.7762
# Epoch: 90 Training loss: 96.3883
# Epoch: 91 Training loss: 97.8140
# Epoch: 92 Training loss: 99.7175
# Epoch: 93 Training loss: 98.5997
# Epoch: 94 Training loss: 100.2356
# Epoch: 95 Training loss: 99.0646
# Epoch: 96 Training loss: 94.9431
# Epoch: 97 Training loss: 98.0390
# Epoch: 98 Training loss: 97.3348
# Epoch: 99 Training loss: 96.0600
# Epoch: 100 Training loss: 98.6281

# %%
# Training the rVAE on cards-iii
in_dim = (48, 48)  # Input dimensions of the dataset i.e., shape of each card's image

# Initialize probabilistic VAE model ->
# (invariances=None: vanilla VAE
#  invariances=['r']: enforces rotational invariance
#  invariances=['t']: enforces translational invariance
#  invariances=['r', 't']: enforces invariance to rotations & translations
#  etc.)
rvae3 = pv.models.iVAE(in_dim, latent_dim=2, # Number of latent dimensions other than the invariancies
                      hidden_dim_e = [256, 256],  # corresponds to the number of neurons in the hidden layers of the encoder
                     hidden_dim_d = [256, 256],  # corresponds to the number of neurons in the hidden layers of the decoder
                     invariances=['r'], seed=1)

# Initialize SVI trainer
trainer3 = pv.trainers.SVItrainer(rvae3)
# Train for n epochs:
for e in range(100):
    trainer3.step(train_loader3)
    trainer3.print_statistics()

# Saving the weights of the trained rVAE model on cards-iii
#rvae3.save_weights('/content/drive/MyDrive/VAE Review/rvae_files/rave3')
# Out:
# Epoch: 1 Training loss: 604.4029
# Epoch: 2 Training loss: 320.6197
# Epoch: 3 Training loss: 257.7208
# Epoch: 4 Training loss: 226.2271
# Epoch: 5 Training loss: 198.8971
# Epoch: 6 Training loss: 175.5913
# Epoch: 7 Training loss: 158.1917
# Epoch: 8 Training loss: 144.1225
# Epoch: 9 Training loss: 133.6725
# Epoch: 10 Training loss: 127.5925
# Epoch: 11 Training loss: 124.3578
# Epoch: 12 Training loss: 119.5495
# Epoch: 13 Training loss: 120.0846
# Epoch: 14 Training loss: 113.9859
# Epoch: 15 Training loss: 114.4519
# Epoch: 16 Training loss: 111.6624
# Epoch: 17 Training loss: 110.0943
# Epoch: 18 Training loss: 107.3116
# Epoch: 19 Training loss: 106.5117
# Epoch: 20 Training loss: 105.8929
# Epoch: 21 Training loss: 104.5181
# Epoch: 22 Training loss: 108.3007
# Epoch: 23 Training loss: 106.7762
# Epoch: 24 Training loss: 102.5066
# Epoch: 25 Training loss: 101.7744
# Epoch: 26 Training loss: 100.7593
# Epoch: 27 Training loss: 99.8979
# Epoch: 28 Training loss: 99.9247
# Epoch: 29 Training loss: 99.4899
# Epoch: 30 Training loss: 97.7541
# Epoch: 31 Training loss: 99.0912
# Epoch: 32 Training loss: 97.9755
# Epoch: 33 Training loss: 95.5449
# Epoch: 34 Training loss: 95.1522
# Epoch: 35 Training loss: 94.6648
# Epoch: 36 Training loss: 94.5030
# Epoch: 37 Training loss: 95.6228
# Epoch: 38 Training loss: 94.2920
# Epoch: 39 Training loss: 95.1551
# Epoch: 40 Training loss: 95.0882
# Epoch: 41 Training loss: 93.1103
# Epoch: 42 Training loss: 91.9831
# Epoch: 43 Training loss: 94.2521
# Epoch: 44 Training loss: 93.3122
# Epoch: 45 Training loss: 93.1517
# Epoch: 46 Training loss: 92.8523
# Epoch: 47 Training loss: 91.5094
# Epoch: 48 Training loss: 91.3446
# Epoch: 49 Training loss: 92.2625
# Epoch: 50 Training loss: 92.9260
# Epoch: 51 Training loss: 90.5090
# Epoch: 52 Training loss: 92.2385
# Epoch: 53 Training loss: 91.0980
# Epoch: 54 Training loss: 92.1941
# Epoch: 55 Training loss: 94.9310
# Epoch: 56 Training loss: 90.1524
# Epoch: 57 Training loss: 89.8255
# Epoch: 58 Training loss: 91.0102
# Epoch: 59 Training loss: 90.0869
# Epoch: 60 Training loss: 90.6172
# Epoch: 61 Training loss: 91.4807
# Epoch: 62 Training loss: 90.0465
# Epoch: 63 Training loss: 88.6468
# Epoch: 64 Training loss: 88.8401
# Epoch: 65 Training loss: 93.1073
# Epoch: 66 Training loss: 87.6670
# Epoch: 67 Training loss: 88.2300
# Epoch: 68 Training loss: 89.3136
# Epoch: 69 Training loss: 90.0340
# Epoch: 70 Training loss: 88.7397
# Epoch: 71 Training loss: 91.5730
# Epoch: 72 Training loss: 87.2571
# Epoch: 73 Training loss: 89.5786
# Epoch: 74 Training loss: 87.6627
# Epoch: 75 Training loss: 90.7246
# Epoch: 76 Training loss: 88.8955
# Epoch: 77 Training loss: 87.9222
# Epoch: 78 Training loss: 88.2109
# Epoch: 79 Training loss: 90.8962
# Epoch: 80 Training loss: 87.9027
# Epoch: 81 Training loss: 87.4663
# Epoch: 82 Training loss: 89.3481
# Epoch: 83 Training loss: 88.8366
# Epoch: 84 Training loss: 87.4070
# Epoch: 85 Training loss: 88.5071
# Epoch: 86 Training loss: 89.2756
# Epoch: 87 Training loss: 87.7229
# Epoch: 88 Training loss: 87.1886
# Epoch: 89 Training loss: 86.2943
# Epoch: 90 Training loss: 91.3071
# Epoch: 91 Training loss: 86.9247
# Epoch: 92 Training loss: 87.5209
# Epoch: 93 Training loss: 86.6414
# Epoch: 94 Training loss: 86.7581
# Epoch: 95 Training loss: 87.8822
# Epoch: 96 Training loss: 86.8103
# Epoch: 97 Training loss: 87.2736
# Epoch: 98 Training loss: 87.6442
# Epoch: 99 Training loss: 88.1724
# Epoch: 100 Training loss: 87.0511

# %%
# Training the rVAE on cards-iv

in_dim = (48, 48)  # Input dimensions of the dataset i.e., shape of each card's image

# Initialize probabilistic VAE model ->
# (invariances=None: vanilla VAE
#  invariances=['r']: enforces rotational invariance
#  invariances=['t']: enforces translational invariance
#  invariances=['r', 't']: enforces invariance to rotations & translations
#  etc.)
rvae4 = pv.models.iVAE(in_dim, latent_dim=2,  # Number of latent dimensions other than the invariancies
                      hidden_dim_e = [512, 512],  # corresponds to the number of neurons in the hidden layers of the encoder
                     hidden_dim_d = [512, 512],  # corresponds to the number of neurons in the hidden layers of the decoder
                     invariances=['r'], seed=0)

# Initialize SVI trainer
trainer4 = pv.trainers.SVItrainer(rvae4)
# Train for n epochs:
for e in range(100):
    trainer4.step(train_loader4)
    trainer4.print_statistics()

# Saving the weights of the trained rVAE model on cards-iv
#rvae4.save_weights('/content/drive/MyDrive/VAE Review/rvae_files/rave4')
# Out:
# Epoch: 1 Training loss: 684.2786
# Epoch: 2 Training loss: 374.6269
# Epoch: 3 Training loss: 328.6235
# Epoch: 4 Training loss: 288.6880
# Epoch: 5 Training loss: 265.0080
# Epoch: 6 Training loss: 247.7445
# Epoch: 7 Training loss: 229.6637
# Epoch: 8 Training loss: 218.8539
# Epoch: 9 Training loss: 207.7961
# Epoch: 10 Training loss: 196.8379
# Epoch: 11 Training loss: 188.5058
# Epoch: 12 Training loss: 179.8892
# Epoch: 13 Training loss: 179.0521
# Epoch: 14 Training loss: 169.1623
# Epoch: 15 Training loss: 170.9717
# Epoch: 16 Training loss: 161.1767
# Epoch: 17 Training loss: 161.1293
# Epoch: 18 Training loss: 154.5304
# Epoch: 19 Training loss: 157.1053
# Epoch: 20 Training loss: 151.6132
# Epoch: 21 Training loss: 148.1826
# Epoch: 22 Training loss: 148.9621
# Epoch: 23 Training loss: 147.8032
# Epoch: 24 Training loss: 146.2781
# Epoch: 25 Training loss: 143.6532
# Epoch: 26 Training loss: 143.4321
# Epoch: 27 Training loss: 138.7462
# Epoch: 28 Training loss: 142.0392
# Epoch: 29 Training loss: 137.5224
# Epoch: 30 Training loss: 140.3314
# Epoch: 31 Training loss: 142.2432
# Epoch: 32 Training loss: 134.4758
# Epoch: 33 Training loss: 132.8748
# Epoch: 34 Training loss: 138.5602
# Epoch: 35 Training loss: 135.3197
# Epoch: 36 Training loss: 133.3569
# Epoch: 37 Training loss: 130.3365
# Epoch: 38 Training loss: 136.9150
# Epoch: 39 Training loss: 127.8018
# Epoch: 40 Training loss: 130.8668
# Epoch: 41 Training loss: 129.3608
# Epoch: 42 Training loss: 129.6372
# Epoch: 43 Training loss: 130.8557
# Epoch: 44 Training loss: 132.5970
# Epoch: 45 Training loss: 131.5098
# Epoch: 46 Training loss: 131.0425
# Epoch: 47 Training loss: 129.3860
# Epoch: 48 Training loss: 125.3577
# Epoch: 49 Training loss: 125.7124
# Epoch: 50 Training loss: 127.6021
# Epoch: 51 Training loss: 128.0730
# Epoch: 52 Training loss: 124.9233
# Epoch: 53 Training loss: 121.8054
# Epoch: 54 Training loss: 124.7318
# Epoch: 55 Training loss: 127.7558
# Epoch: 56 Training loss: 131.4534
# Epoch: 57 Training loss: 126.8735
# Epoch: 58 Training loss: 125.5289
# Epoch: 59 Training loss: 123.5249
# Epoch: 60 Training loss: 120.6229
# Epoch: 61 Training loss: 124.5852
# Epoch: 62 Training loss: 125.5774
# Epoch: 63 Training loss: 126.2227
# Epoch: 64 Training loss: 123.8674
# Epoch: 65 Training loss: 122.8194
# Epoch: 66 Training loss: 122.5781
# Epoch: 67 Training loss: 119.8534
# Epoch: 68 Training loss: 123.0565
# Epoch: 69 Training loss: 125.4618
# Epoch: 70 Training loss: 125.6271
# Epoch: 71 Training loss: 121.0632
# Epoch: 72 Training loss: 119.0188
# Epoch: 73 Training loss: 123.1564
# Epoch: 74 Training loss: 122.2242
# Epoch: 75 Training loss: 123.4615
# Epoch: 76 Training loss: 122.0676
# Epoch: 77 Training loss: 120.1514
# Epoch: 78 Training loss: 119.9732
# Epoch: 79 Training loss: 119.1990
# Epoch: 80 Training loss: 117.9230
# Epoch: 81 Training loss: 120.8387
# Epoch: 82 Training loss: 121.8114
# Epoch: 83 Training loss: 120.3291
# Epoch: 84 Training loss: 119.7413
# Epoch: 85 Training loss: 122.1578
# Epoch: 86 Training loss: 119.5766
# Epoch: 87 Training loss: 118.8923
# Epoch: 88 Training loss: 120.3641
# Epoch: 89 Training loss: 118.6149
# Epoch: 90 Training loss: 118.2411
# Epoch: 91 Training loss: 121.3658
# Epoch: 92 Training loss: 120.5532
# Epoch: 93 Training loss: 120.6228
# Epoch: 94 Training loss: 121.3881
# Epoch: 95 Training loss: 123.3609
# Epoch: 96 Training loss: 120.1005
# Epoch: 97 Training loss: 118.5895
# Epoch: 98 Training loss: 117.4237
# Epoch: 99 Training loss: 118.7221
# Epoch: 100 Training loss: 120.3276

# %% [markdown]
# # Visulizing the results
# Saved weights will be downloaded in the corresponding sections

# %% [markdown]
# ## cards-i
# Low rotation (12 deg) and low shear (1 deg)

# %%
# First let's just visualize some randomly picked samples from the input dataset

np.random.seed(1)  # fix seed so that we get the same samples displayed at every run
fig, axes = plt.subplots(10, 10, figsize=(5, 5),
                         subplot_kw={'xticks':[], 'yticks':[]},
                         gridspec_kw=dict(hspace=0.1, wspace=0.1))

for ax in axes.flat:
    i = np.random.randint(len(cards_all1))
    ax.imshow(cards_all1[i], cmap='gnuplot', interpolation='nearest')

# %%
# Initializing a new network
rvae1 = pv.models.iVAE((48, 48), latent_dim=2,
                      hidden_dim_e = [256,256],
                     hidden_dim_d = [256,256],
                     invariances=['r'], seed=0)

# Download the weigths file
# !gdown 1xTiHFNo6IU0wkovEsIznKbmna3vgAHdI

# Loading the saved weights into the newly initialized network
rvae1.load_weights('rvae1.pt')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1xTiHFNo6IU0wkovEsIznKbmna3vgAHdI
# To: /content/rvae1.pt
# 100% 3.17M/3.17M [00:00<00:00, 234MB/s]

# %%
# Decoded latent space:
# The latent space is uniformly sampled in z1-z2 latent dimensions.
# These points are decoded back into the image space and are plotted in their corresponding latent space positions


rvae1.manifold2d(d = 9)   # d corresponds to the number of points sampled in each latent dimension
# Out:
# tensor([[[1.1468e-09, 2.8326e-09, 5.5827e-09,  ..., 5.0601e-14,
#           2.4689e-14, 1.0278e-14],
#          [6.0838e-10, 1.7792e-09, 4.3682e-09,  ..., 2.8518e-14,
#           1.0310e-14, 3.2649e-15],
#          [2.8303e-10, 9.5444e-10, 2.8350e-09,  ..., 1.1542e-14,
#           3.3791e-15, 1.4093e-15],
#          ...,
#          [1.0017e-10, 9.9368e-11, 1.5708e-10,  ..., 1.7478e-10,
#           8.8669e-11, 4.5499e-11],
#          [7.4009e-11, 1.0632e-10, 2.6144e-10,  ..., 1.6659e-10,
#           9.2288e-11, 4.8458e-11],
#          [7.6181e-11, 1.6367e-10, 3.7144e-10,  ..., 1.3759e-10,
#           8.7844e-11, 4.9848e-11]],
#
#         [[1.5518e-09, 3.0411e-09, 4.5469e-09,  ..., 7.5811e-14,
#           2.2678e-14, 4.7467e-15],
#          [1.0184e-09, 2.2909e-09, 4.1141e-09,  ..., 2.3555e-14,
#           4.4833e-15, 1.1043e-15],
#          [6.2340e-10, 1.6172e-09, 3.3377e-09,  ..., 4.5001e-15,
#           1.1795e-15, 8.6256e-16],
#          ...,
#          [1.2733e-10, 1.0180e-10, 1.2020e-10,  ..., 1.8147e-11,
#           1.1329e-11, 8.2733e-12],
#          [8.0199e-11, 9.1945e-11, 1.8672e-10,  ..., 1.4278e-11,
#           9.6147e-12, 7.0982e-12],
#          [7.1721e-11, 1.2903e-10, 3.2517e-10,  ..., 9.0005e-12,
#           6.7722e-12, 5.4161e-12]],
#
#         [[1.1628e-09, 1.8251e-09, 2.4374e-09,  ..., 4.6696e-14,
#           9.5635e-15, 1.6647e-15],
#          [9.1453e-10, 1.6321e-09, 2.3897e-09,  ..., 1.0547e-14,
#           1.6825e-15, 4.8460e-16],
#          [6.0754e-10, 1.3202e-09, 2.1922e-09,  ..., 1.8758e-15,
#           5.6389e-16, 6.1939e-16],
#          ...,
#          [1.2426e-10, 9.3872e-11, 1.0547e-10,  ..., 3.7802e-12,
#           3.6371e-12, 3.7236e-12],
#          [7.3063e-11, 8.0534e-11, 1.6068e-10,  ..., 1.9971e-12,
#           1.9942e-12, 2.1960e-12],
#          [6.2682e-11, 1.1085e-10, 2.8144e-10,  ..., 1.1480e-12,
#           1.0180e-12, 1.1199e-12]],
#
#         ...,
#
#         [[6.1861e-14, 8.3719e-14, 1.3746e-13,  ..., 2.1955e-14,
#           4.1972e-14, 5.1909e-14],
#          [6.5751e-14, 7.3593e-14, 1.0075e-13,  ..., 4.9928e-14,
#           6.5475e-14, 7.8716e-14],
#          [1.2584e-13, 1.0275e-13, 1.0857e-13,  ..., 8.8556e-14,
#           1.1228e-13, 1.3912e-13],
#          ...,
#          [6.2754e-15, 5.2798e-15, 3.8303e-15,  ..., 4.7516e-16,
#           1.7150e-16, 8.6253e-17],
#          [3.9582e-15, 3.0168e-15, 2.2419e-15,  ..., 9.5679e-16,
#           3.1733e-16, 1.3788e-16],
#          [2.3719e-15, 1.8221e-15, 1.6177e-15,  ..., 1.6864e-15,
#           5.5317e-16, 2.1626e-16]],
#
#         [[8.6079e-16, 7.1285e-16, 8.9361e-16,  ..., 2.7399e-14,
#           3.2401e-14, 3.6674e-14],
#          [3.8584e-15, 2.0475e-15, 1.4385e-15,  ..., 3.6349e-14,
#           4.3326e-14, 5.1608e-14],
#          [2.4098e-14, 1.2526e-14, 6.7622e-15,  ..., 5.4632e-14,
#           6.8539e-14, 8.4987e-14],
#          ...,
#          [4.6963e-15, 3.8491e-15, 2.6531e-15,  ..., 1.6770e-15,
#           4.1104e-16, 1.3885e-16],
#          [2.9731e-15, 2.1527e-15, 1.5843e-15,  ..., 4.7804e-15,
#           1.1156e-15, 2.7282e-16],
#          [1.7204e-15, 1.2945e-15, 1.1466e-15,  ..., 1.1058e-14,
#           3.2439e-15, 7.9541e-16]],
#
#         [[2.7453e-16, 1.4615e-16, 9.2514e-17,  ..., 1.2583e-14,
#           1.4160e-14, 1.5970e-14],
#          [1.6602e-15, 9.3389e-16, 5.2700e-16,  ..., 1.4819e-14,
#           1.7501e-14, 2.0669e-14],
#          [6.1294e-15, 4.6263e-15, 3.1280e-15,  ..., 2.0107e-14,
#           2.5077e-14, 3.1391e-14],
#          ...,
#          [4.8091e-15, 3.8747e-15, 2.6883e-15,  ..., 1.8634e-14,
#           1.0004e-14, 4.4638e-15],
#          [2.9565e-15, 2.0426e-15, 1.6176e-15,  ..., 2.0486e-14,
#           1.1562e-14, 5.7650e-15],
#          [1.6365e-15, 1.2578e-15, 1.1489e-15,  ..., 2.6708e-14,
#           1.4104e-14, 7.3594e-15]]])

# %% [markdown]
# Latent Distributions:
# Input images are represented as points in the latent space using the encoder
# These points are then colored with various ground-truth properties to visualize their distribution

# %%
z_mean1, z_sd1 = rvae1.encode(cards_all1)   # Encoding the full input dataset
# z_mean1: mean of the latent space representation of the input dataset,
# z_sd1: standard deviation of the latent space representation of the input dataset,
# 0th column corresponds to angle and then the regular latent dimensions (First invariant dimensions and then regular latent dimensions)


# Latent distribution colored using the suit of each image
fig, ax = plt.subplots(1, 2, figsize =(14, 6))
im = ax[0].scatter(z_mean1[:,-1], z_mean1[:,-2], c=labels_all1, s=1, cmap='jet')
ax[0].set_xlabel("$z_1$", fontsize=14)
ax[0].set_ylabel("$z_2$", fontsize=14)
cbar = fig.colorbar(im, ax=ax[0], shrink=.8)
cbar.set_label("Suit", fontsize=14)
cbar.ax.tick_params(labelsize=10)

# Latent distribution colored using the ground truth shear applied on each image
im = ax[1].scatter(z_mean1[:,-1], z_mean1[:,-2], c=shears_all1[:,0], s=1, cmap='jet')
ax[1].set_xlabel("$z_1$", fontsize=14)
ax[1].set_ylabel("$z_2$", fontsize=14)
cbar = fig.colorbar(im, ax=ax[1], shrink=.8)
cbar.set_label("Shear", fontsize=14)
cbar.ax.tick_params(labelsize=10)


plt.show()

# %%
# Finally the plot of encoded angle vs. ground truth rotation applied to the images.
# The points are colored using the suit of the images.

fig, ax = plt.subplots(figsize = (7,7))
ax.scatter(torch.deg2rad(angles_all1), z_mean1[:,0], c = labels_all1, s =1, cmap = 'jet')
ax.set_xlabel("ground truth", fontsize=14)
ax.set_ylabel("angular encoding", fontsize=14)
# Out:
# Text(0, 0.5, 'angular encoding')

# %% [markdown]
# ## cards-ii
# Low rotation (12 deg) High shear (20deg)

# %%
# First let's just visualize some randomly picked samples from the input dataset

np.random.seed(1)  # fix seed so that we get the same samples displayed at every run
fig, axes = plt.subplots(5, 5, figsize=(8, 8),
                         subplot_kw={'xticks':[], 'yticks':[]},
                         gridspec_kw=dict(hspace=0.1, wspace=0.1))

for ax in axes.flat:
    i = np.random.randint(len(cards_all2))
    ax.imshow(cards_all2[i], cmap='gnuplot', interpolation='nearest')

# %%
# Initializing a new network
rvae2 = pv.models.iVAE((48, 48), latent_dim=2,
                      hidden_dim_e = [512,512],
                     hidden_dim_d = [512,512],
                     invariances=['r'], seed=0)

# Download the weigths file
# !gdown 1-1xnfzcKQuZ1qJJbkiuz6nglwIpZXSx8

# Loading the saved weights into the newly initialized network
rvae2.load_weights('rvae2.pt')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-1xnfzcKQuZ1qJJbkiuz6nglwIpZXSx8
# To: /content/rvae2.pt
# 100% 7.90M/7.90M [00:00<00:00, 26.3MB/s]

# %%
# Decoded latent space:
# The latent space is uniformly sampled in z1-z2 latent dimensions.
# These points are decoded back into the image space and are plotted in their corresponding latent space positions

rvae2.manifold2d(d = 9)  # d corresponds to the number of points sampled in each latent dimension
# Out:
# tensor([[[3.9037e-14, 6.0535e-14, 8.7713e-14,  ..., 9.4729e-15,
#           9.4860e-15, 9.2481e-15],
#          [5.6135e-14, 7.1412e-14, 9.2486e-14,  ..., 9.0920e-15,
#           8.9081e-15, 8.4188e-15],
#          [1.1814e-13, 1.1932e-13, 1.2627e-13,  ..., 9.4188e-15,
#           8.9379e-15, 8.5208e-15],
#          ...,
#          [1.8177e-12, 2.4347e-12, 5.7659e-12,  ..., 7.6780e-14,
#           4.1996e-14, 2.9992e-14],
#          [1.1259e-12, 2.5575e-12, 5.3991e-12,  ..., 1.3707e-13,
#           7.4020e-14, 4.6033e-14],
#          [1.1256e-12, 2.2667e-12, 3.6075e-12,  ..., 2.0622e-13,
#           1.3570e-13, 7.3620e-14]],
#
#         [[9.4906e-15, 1.4104e-14, 2.4267e-14,  ..., 4.8643e-15,
#           3.5226e-15, 2.9307e-15],
#          [1.0062e-14, 1.2169e-14, 1.8165e-14,  ..., 4.1549e-15,
#           3.2327e-15, 2.8578e-15],
#          [1.3199e-14, 1.4179e-14, 1.7181e-14,  ..., 3.6432e-15,
#           3.1770e-15, 2.8623e-15],
#          ...,
#          [1.6161e-12, 1.5064e-12, 1.6120e-12,  ..., 7.6933e-14,
#           5.8031e-14, 4.5862e-14],
#          [8.3354e-13, 8.3418e-13, 7.9698e-13,  ..., 1.3797e-13,
#           8.3984e-14, 6.5964e-14],
#          [4.9910e-13, 4.4190e-13, 3.7604e-13,  ..., 2.7989e-13,
#           1.5800e-13, 1.0391e-13]],
#
#         [[3.7766e-14, 6.4752e-14, 1.5861e-13,  ..., 2.3515e-15,
#           2.3130e-15, 2.1908e-15],
#          [3.2463e-14, 4.6134e-14, 1.0120e-13,  ..., 3.0481e-15,
#           2.9718e-15, 2.4103e-15],
#          [3.3740e-14, 3.8773e-14, 7.1545e-14,  ..., 4.3269e-15,
#           3.3076e-15, 2.2938e-15],
#          ...,
#          [2.4512e-12, 1.9694e-12, 1.8326e-12,  ..., 1.7378e-13,
#           1.4246e-13, 1.0779e-13],
#          [9.2263e-13, 8.1632e-13, 8.2662e-13,  ..., 2.9111e-13,
#           2.1101e-13, 1.5606e-13],
#          [4.3789e-13, 4.2690e-13, 4.3019e-13,  ..., 4.9763e-13,
#           3.6502e-13, 2.5555e-13]],
#
#         ...,
#
#         [[1.7320e-14, 2.8190e-14, 4.9894e-14,  ..., 6.7159e-13,
#           1.7920e-12, 8.4130e-12],
#          [1.3693e-14, 1.8620e-14, 3.0644e-14,  ..., 2.0430e-12,
#           9.9041e-12, 3.9503e-11],
#          [1.4507e-14, 1.4643e-14, 2.0036e-14,  ..., 1.2544e-11,
#           5.8604e-11, 1.5225e-10],
#          ...,
#          [5.3445e-11, 1.0614e-10, 1.9584e-10,  ..., 4.2709e-12,
#           3.9691e-12, 3.7897e-12],
#          [4.5458e-11, 8.9475e-11, 8.9942e-11,  ..., 2.9306e-12,
#           2.6218e-12, 2.3835e-12],
#          [3.9500e-11, 5.2460e-11, 4.2201e-11,  ..., 2.2463e-12,
#           1.7899e-12, 1.5194e-12]],
#
#         [[1.8186e-14, 2.7094e-14, 4.4274e-14,  ..., 2.1787e-13,
#           4.6032e-13, 1.8122e-12],
#          [1.7891e-14, 2.1887e-14, 3.2765e-14,  ..., 8.0031e-13,
#           2.9999e-12, 1.3088e-11],
#          [2.1089e-14, 2.0587e-14, 2.4962e-14,  ..., 5.3132e-12,
#           2.0869e-11, 7.4756e-11],
#          ...,
#          [4.1261e-10, 8.6196e-10, 8.7715e-10,  ..., 3.0437e-12,
#           3.1177e-12, 3.2487e-12],
#          [2.2950e-10, 3.1055e-10, 1.9641e-10,  ..., 2.2752e-12,
#           2.0387e-12, 1.9355e-12],
#          [1.0772e-10, 9.4180e-11, 6.1638e-11,  ..., 2.2451e-12,
#           1.6416e-12, 1.3765e-12]],
#
#         [[3.0032e-14, 3.0458e-14, 4.2305e-14,  ..., 3.1649e-14,
#           6.1325e-14, 2.1899e-13],
#          [3.3749e-14, 2.9395e-14, 3.1973e-14,  ..., 1.4810e-13,
#           4.9181e-13, 1.6624e-12],
#          [3.8285e-14, 3.8105e-14, 3.6902e-14,  ..., 1.2824e-12,
#           3.5770e-12, 8.1498e-12],
#          ...,
#          [2.5359e-09, 1.4882e-09, 4.7779e-10,  ..., 7.8853e-12,
#           5.1142e-12, 4.3923e-12],
#          [9.1656e-10, 2.9066e-10, 1.3063e-10,  ..., 7.6198e-12,
#           3.5282e-12, 2.3868e-12],
#          [1.9935e-10, 8.5668e-11, 6.1150e-11,  ..., 8.5237e-12,
#           3.8439e-12, 1.8297e-12]]])

# %% [markdown]
# Latent Distributions:
# Input images are represented as points in the latent space using the encoder
# These points are then colored with various ground-truth properties to visualize their distribution

# %%
z_mean2, z_sd2 = rvae2.encode(cards_all2)  # Encoding the full input dataset
# z_mean2: mean of the latent space representation of the input dataset,
# z_sd2: standard deviation of the latent space representation of the input dataset,
# 0th column corresponds to angle and then the regular latent dimensions (First invariant dimensions and then regular latent dimensions)


# Latent distribution colored using the suit of each image
fig, ax = plt.subplots(1, 2, figsize =(14, 6))
im = ax[0].scatter(z_mean2[:,-1], z_mean2[:,-2], c=labels_all2, s=1, cmap='jet')
ax[0].set_xlabel("$z_1$", fontsize=14)
ax[0].set_ylabel("$z_2$", fontsize=14)
cbar = fig.colorbar(im, ax=ax[0], shrink=.8)
cbar.set_label("Suit", fontsize=14)
cbar.ax.tick_params(labelsize=10)

# Latent distribution colored using the ground-truth shear of each image
im = ax[1].scatter(z_mean2[:,-1], z_mean2[:,-2], c=shears_all2[:,0], s=1, cmap='jet')
ax[1].set_xlabel("$z_1$", fontsize=14)
ax[1].set_ylabel("$z_2$", fontsize=14)
cbar = fig.colorbar(im, ax=ax[1], shrink=.8)
cbar.set_label("Shear", fontsize=14)
cbar.ax.tick_params(labelsize=10)
plt.show()

# %%
# Finally the plot of encoded angle vs. ground truth rotation applied to the images.
# The points are colored using the suit of the images.

fig, ax = plt.subplots(figsize = (7,7))
ax.scatter(torch.deg2rad(angles_all2), z_mean2[:,0], c = labels_all2, s =1, cmap = 'jet')
ax.set_xlabel("ground truth", fontsize=14)
ax.set_ylabel("angular encoding", fontsize=14)
# Out:
# Text(0, 0.5, 'angular encoding')

# %% [markdown]
# ## cards-iii
# High rotation (120 degrees) and Low shear (1 degree)

# %%
# First let's just visualize some randomly picked samples from the input dataset

np.random.seed(1)  # fix seed so that we get the same samples displayed at every run
fig, axes = plt.subplots(10, 10, figsize=(5, 5),
                         subplot_kw={'xticks':[], 'yticks':[]},
                         gridspec_kw=dict(hspace=0.1, wspace=0.1))

for ax in axes.flat:
    i = np.random.randint(len(cards_all3))
    ax.imshow(cards_all3[i], cmap='gnuplot', interpolation='nearest')

# %%
# Initializing a new network
rvae3 = pv.models.iVAE((48, 48), latent_dim=2,
                      hidden_dim_e = [256,256],
                     hidden_dim_d = [256,256],
                     invariances=['r'], seed=0)

# Download the weigths file
# !gdown 1-2RLvpje9EVphg4o5ybKXlN3WVqCQdhT

# Loading the saved weights into the newly initialized network
rvae3.load_weights('rvae3.pt')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-2RLvpje9EVphg4o5ybKXlN3WVqCQdhT
# To: /content/rvae3.pt
# 100% 3.17M/3.17M [00:00<00:00, 216MB/s]

# %%
# Decoded latent space:
# The latent space is uniformly sampled in z1-z2 latent dimensions.
# These points are decoded back into the image space and are plotted in their corresponding latent space positions

rvae3.manifold2d(d = 9)   # d corresponds to the number of points sampled in each latent dimension
# Out:
# tensor([[[1.4053e-14, 1.3226e-14, 1.5620e-14,  ..., 2.0938e-13,
#           1.5425e-13, 1.0883e-13],
#          [2.7584e-14, 1.9949e-14, 1.8625e-14,  ..., 2.3502e-13,
#           1.5839e-13, 1.0664e-13],
#          [7.1736e-14, 4.1993e-14, 3.0056e-14,  ..., 2.6221e-13,
#           1.6904e-13, 1.0920e-13],
#          ...,
#          [1.0634e-10, 3.2817e-10, 9.8305e-10,  ..., 1.1104e-09,
#           8.8409e-10, 5.4440e-10],
#          [1.8410e-10, 4.4601e-10, 1.1133e-09,  ..., 6.3847e-10,
#           7.2802e-10, 6.8155e-10],
#          [2.0606e-10, 4.3053e-10, 9.2573e-10,  ..., 2.2664e-10,
#           3.2803e-10, 4.3887e-10]],
#
#         [[3.2787e-14, 9.4262e-15, 5.8202e-15,  ..., 1.9432e-13,
#           1.5017e-13, 1.1885e-13],
#          [2.0210e-13, 3.6907e-14, 1.0634e-14,  ..., 2.1148e-13,
#           1.6278e-13, 1.2471e-13],
#          [9.8967e-13, 2.3688e-13, 4.3908e-14,  ..., 2.5645e-13,
#           1.9441e-13, 1.3780e-13],
#          ...,
#          [9.5462e-12, 4.0587e-11, 1.6344e-10,  ..., 3.8553e-09,
#           2.7617e-09, 1.6089e-09],
#          [2.9572e-11, 9.3977e-11, 3.0023e-10,  ..., 4.0621e-09,
#           4.1512e-09, 3.7321e-09],
#          [5.6349e-11, 1.4424e-10, 3.2926e-10,  ..., 2.2828e-09,
#           2.9916e-09, 3.6082e-09]],
#
#         [[8.5149e-14, 1.5343e-14, 6.2126e-15,  ..., 1.9795e-13,
#           1.6021e-13, 1.3059e-13],
#          [5.5359e-13, 8.8292e-14, 1.5952e-14,  ..., 2.1051e-13,
#           1.6791e-13, 1.3065e-13],
#          [2.3282e-12, 5.9735e-13, 9.5184e-14,  ..., 2.4683e-13,
#           1.9171e-13, 1.3628e-13],
#          ...,
#          [2.8940e-12, 1.4960e-11, 7.0736e-11,  ..., 5.3862e-10,
#           3.6163e-10, 2.4193e-10],
#          [1.2957e-11, 4.8527e-11, 1.5765e-10,  ..., 1.6113e-09,
#           1.0406e-09, 6.4268e-10],
#          [3.4382e-11, 8.9490e-11, 1.7885e-10,  ..., 2.2087e-09,
#           2.3117e-09, 1.9771e-09]],
#
#         ...,
#
#         [[2.4126e-15, 1.6256e-15, 9.9049e-16,  ..., 2.8541e-15,
#           3.0274e-15, 3.3684e-15],
#          [4.4433e-15, 2.7238e-15, 1.6603e-15,  ..., 4.4144e-15,
#           5.3903e-15, 6.6659e-15],
#          [1.0319e-14, 5.8039e-15, 3.2302e-15,  ..., 9.2338e-15,
#           1.2557e-14, 1.6582e-14],
#          ...,
#          [6.1032e-15, 5.0396e-15, 4.2467e-15,  ..., 8.1061e-13,
#           2.7078e-12, 7.2299e-12],
#          [6.9672e-15, 6.2824e-15, 6.2489e-15,  ..., 1.3892e-13,
#           4.4231e-13, 1.3349e-12],
#          [8.7165e-15, 8.5964e-15, 9.0266e-15,  ..., 4.3059e-14,
#           1.0692e-13, 2.6931e-13]],
#
#         [[1.6100e-15, 1.1171e-15, 6.8706e-16,  ..., 4.2317e-15,
#           5.0471e-15, 6.1917e-15],
#          [2.7352e-15, 1.7431e-15, 1.0770e-15,  ..., 7.6632e-15,
#           1.0218e-14, 1.3672e-14],
#          [5.9470e-15, 3.4163e-15, 1.9199e-15,  ..., 1.7892e-14,
#           2.6073e-14, 3.7310e-14],
#          ...,
#          [3.1651e-15, 2.9394e-15, 2.6972e-15,  ..., 1.0939e-12,
#           3.9237e-12, 1.2138e-11],
#          [4.7855e-15, 4.7903e-15, 4.3016e-15,  ..., 1.2823e-13,
#           4.9884e-13, 1.7879e-12],
#          [7.6480e-15, 7.2391e-15, 5.5826e-15,  ..., 1.9327e-14,
#           6.4683e-14, 2.3467e-13]],
#
#         [[1.0172e-15, 6.5955e-16, 4.8408e-16,  ..., 1.7292e-14,
#           2.5024e-14, 3.6287e-14],
#          [1.6564e-15, 9.5372e-16, 6.3707e-16,  ..., 3.9606e-14,
#           6.3098e-14, 9.9292e-14],
#          [3.6358e-15, 1.7976e-15, 9.9343e-16,  ..., 1.1535e-13,
#           1.9986e-13, 3.1142e-13],
#          ...,
#          [1.7797e-15, 1.8899e-15, 1.9667e-15,  ..., 4.8745e-12,
#           1.7883e-11, 5.4180e-11],
#          [2.9914e-15, 3.0249e-15, 2.7470e-15,  ..., 4.3944e-13,
#           1.8531e-12, 6.8732e-12],
#          [4.7187e-15, 4.2087e-15, 3.2982e-15,  ..., 4.0451e-14,
#           1.6919e-13, 6.8693e-13]]])

# %% [markdown]
# Latent Distributions:
# Input images are represented as points in the latent space using the encoder
# These points are then colored with various ground-truth properties to visualize their distribution

# %%
z_mean3, z_sd3 = rvae3.encode(cards_all3)   # Encoding the full input dataset
# z_mean3: mean of the latent space representation of the input dataset,
# z_sd3: standard deviation of the latent space representation of the input dataset,
# 0th column corresponds to angle and then the regular latent dimensions (First invariant dimensions and then regular latent dimensions)


# Latent distribution colored using the suit of each image
fig, ax = plt.subplots(1, 2, figsize =(14, 6))
im = ax[0].scatter(z_mean3[:,-1], z_mean3[:,-2], c=labels_all3, s=1, cmap='jet')
ax[0].set_xlabel("$z_1$", fontsize=14)
ax[0].set_ylabel("$z_2$", fontsize=14)
cbar = fig.colorbar(im, ax=ax[0], shrink=.8)
cbar.set_label("Suit", fontsize=14)
cbar.ax.tick_params(labelsize=10)

# Latent distribution colored using the ground-truth shear of each image
im = ax[1].scatter(z_mean3[:,-1], z_mean3[:,-2], c=shears_all3[:,0], s=1, cmap='jet')
ax[1].set_xlabel("$z_1$", fontsize=14)
ax[1].set_ylabel("$z_2$", fontsize=14)
cbar = fig.colorbar(im, ax=ax[1], shrink=.8)
cbar.set_label("Shear", fontsize=14)
cbar.ax.tick_params(labelsize=10)

plt.show()

# %%
# Finally the plot of encoded angle vs. ground truth rotation applied to the images.
# The points are colored using the suit of the images.

fig, ax = plt.subplots(figsize = (7,7))
ax.scatter(torch.deg2rad(angles_all3), z_mean3[:,0], c = labels_all3, s =10, cmap = 'jet')
ax.set_xlabel("ground truth", fontsize=14)
ax.set_ylabel("angular encoding", fontsize=14)
# Out:
# Text(0, 0.5, 'angular encoding')

# %% [markdown]
# ## cards-iv
# High rotation (120 degrees) and high shear (20 degrees)

# %%
# First let's just visualize some randomly picked samples from the input dataset

np.random.seed(1)  # fix seed so that we get the same samples displayed at every run
fig, axes = plt.subplots(10, 10, figsize=(5, 5),
                         subplot_kw={'xticks':[], 'yticks':[]},
                         gridspec_kw=dict(hspace=0.1, wspace=0.1))

for ax in axes.flat:
    i = np.random.randint(len(cards_all4))
    ax.imshow(cards_all4[i], cmap='gnuplot', interpolation='nearest')

# %%
# Initializing a new network
rvae4 = pv.models.iVAE((48, 48), latent_dim=2,
                      hidden_dim_e = [512,512],
                     hidden_dim_d = [512,512],
                     invariances=['r'], seed=0)

# Download the weigths file
# !gdown 1-7z8pdIf5cpIUxF6SestucWURbhww_Ta

# Loading the saved weights into the newly initialized network
rvae4.load_weights('rvae4.pt')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-7z8pdIf5cpIUxF6SestucWURbhww_Ta
# To: /content/rvae4.pt
# 100% 7.90M/7.90M [00:00<00:00, 38.8MB/s]

# %%
# Decoded latent space:
# The latent space is uniformly sampled in z1-z2 latent dimensions.
# These points are decoded back into the image space and are plotted in their corresponding latent space positions

rvae4.manifold2d(d = 9)   # d corresponds to the number of points sampled in each latent dimension
# Out:
# tensor([[[3.8292e-09, 6.4712e-09, 7.0848e-09,  ..., 6.2728e-13,
#           8.4270e-13, 1.1977e-12],
#          [2.7077e-09, 6.5434e-09, 1.0518e-08,  ..., 9.6054e-13,
#           1.2969e-12, 1.7241e-12],
#          [1.5391e-09, 4.6744e-09, 1.0148e-08,  ..., 1.4152e-12,
#           1.8170e-12, 2.3383e-12],
#          ...,
#          [2.2823e-09, 7.3273e-09, 2.8955e-08,  ..., 2.5266e-08,
#           2.1827e-08, 1.6112e-08],
#          [3.6312e-09, 1.2123e-08, 4.2722e-08,  ..., 1.6703e-08,
#           1.7139e-08, 1.5166e-08],
#          [4.1294e-09, 1.4240e-08, 4.3518e-08,  ..., 1.1648e-08,
#           1.2697e-08, 1.3497e-08]],
#
#         [[1.0983e-08, 1.4027e-08, 1.0273e-08,  ..., 4.2127e-12,
#           2.4834e-12, 2.1887e-12],
#          [1.2484e-08, 2.2166e-08, 2.1828e-08,  ..., 2.6012e-12,
#           2.0702e-12, 2.1231e-12],
#          [1.0056e-08, 3.0034e-08, 4.0458e-08,  ..., 1.9981e-12,
#           1.9921e-12, 2.2609e-12],
#          ...,
#          [1.1325e-09, 3.7605e-09, 1.4414e-08,  ..., 1.6955e-07,
#           1.1704e-07, 8.1027e-08],
#          [1.9910e-09, 6.9176e-09, 2.6162e-08,  ..., 1.5142e-07,
#           9.8190e-08, 6.7960e-08],
#          [2.8278e-09, 9.3128e-09, 2.8821e-08,  ..., 1.0554e-07,
#           7.4526e-08, 5.0702e-08]],
#
#         [[3.9404e-08, 4.3467e-08, 2.4671e-08,  ..., 1.5527e-11,
#           4.2527e-12, 1.4606e-12],
#          [4.9132e-08, 9.2031e-08, 8.4268e-08,  ..., 7.5368e-12,
#           2.2265e-12, 9.4983e-13],
#          [3.8282e-08, 1.1985e-07, 1.7439e-07,  ..., 3.8358e-12,
#           1.4150e-12, 8.4919e-13],
#          ...,
#          [1.0172e-09, 1.4622e-09, 3.7178e-09,  ..., 3.2237e-07,
#           1.4029e-07, 5.7062e-08],
#          [1.2606e-09, 2.2059e-09, 6.7002e-09,  ..., 3.2847e-07,
#           1.8248e-07, 7.6020e-08],
#          [1.5716e-09, 3.1190e-09, 9.5437e-09,  ..., 2.0208e-07,
#           1.5623e-07, 8.2169e-08]],
#
#         ...,
#
#         [[4.2090e-10, 8.9238e-10, 1.5097e-09,  ..., 5.0680e-10,
#           2.0976e-10, 8.8675e-11],
#          [4.6610e-10, 7.4616e-10, 1.3459e-09,  ..., 6.3678e-10,
#           3.4507e-10, 1.6667e-10],
#          [5.7586e-10, 8.9597e-10, 1.4138e-09,  ..., 1.1644e-09,
#           6.6761e-10, 2.9339e-10],
#          ...,
#          [2.6193e-10, 5.1043e-10, 8.8923e-10,  ..., 1.1935e-08,
#           5.7406e-09, 4.6857e-09],
#          [2.4276e-10, 4.6802e-10, 8.1883e-10,  ..., 1.2654e-08,
#           5.6965e-09, 3.4818e-09],
#          [2.5936e-10, 4.8220e-10, 8.5352e-10,  ..., 1.2251e-08,
#           5.9870e-09, 3.1405e-09]],
#
#         [[1.3876e-10, 3.0119e-10, 5.3008e-10,  ..., 1.0365e-09,
#           4.4145e-10, 1.8614e-10],
#          [1.3823e-10, 2.3361e-10, 4.6478e-10,  ..., 1.5923e-09,
#           7.2972e-10, 3.5456e-10],
#          [1.4101e-10, 2.2740e-10, 4.2018e-10,  ..., 2.4348e-09,
#           1.1184e-09, 5.1130e-10],
#          ...,
#          [7.4012e-10, 1.0665e-09, 1.4841e-09,  ..., 5.3462e-09,
#           3.2984e-09, 2.3700e-09],
#          [5.8081e-10, 8.2909e-10, 1.2067e-09,  ..., 4.0112e-09,
#           2.4928e-09, 1.6830e-09],
#          [4.8735e-10, 6.9505e-10, 1.0954e-09,  ..., 3.1264e-09,
#           1.9315e-09, 1.3591e-09]],
#
#         [[5.7747e-11, 7.7334e-11, 7.9481e-11,  ..., 5.0429e-11,
#           3.9212e-11, 3.3109e-11],
#          [6.6145e-11, 8.4130e-11, 1.0534e-10,  ..., 8.2637e-11,
#           6.6495e-11, 4.4541e-11],
#          [6.5001e-11, 8.1895e-11, 1.2498e-10,  ..., 1.1826e-10,
#           9.0801e-11, 4.0790e-11],
#          ...,
#          [7.2626e-10, 1.4601e-09, 3.0606e-09,  ..., 3.0046e-10,
#           2.0370e-10, 1.6127e-10],
#          [6.7532e-10, 1.4554e-09, 2.9218e-09,  ..., 2.2724e-10,
#           1.6710e-10, 1.4245e-10],
#          [6.0927e-10, 1.2689e-09, 2.4889e-09,  ..., 1.5183e-10,
#           1.2591e-10, 1.1511e-10]]])

# %% [markdown]
# Latent Distributions:
# Input images are represented as points in the latent space using the encoder
# These points are then colored with various ground-truth properties to visualize their distribution

# %%
z_mean4, z_sd4 = rvae4.encode(cards_all4[:, None])  # Encoding the full input dataset
# z_mean4: mean of the latent space representation of the input dataset,
# z_sd4: standard deviation of the latent space representation of the input dataset,
# 0th column corresponds to angle and then the regular latent dimensions (First invariant dimensions and then regular latent dimensions)


# Latent distribution colored using the suit of each image
fig, ax = plt.subplots(1, 2, figsize =(14, 6))
im = ax[0].scatter(z_mean4[:,-1], z_mean4[:,-2], c=labels_all4, s=1, cmap='jet')
ax[0].set_xlabel("$z_1$", fontsize=14)
ax[0].set_ylabel("$z_2$", fontsize=14)
cbar = fig.colorbar(im, ax=ax[0], shrink=.8)
cbar.set_label("Suit", fontsize=14)
cbar.ax.tick_params(labelsize=10)


# Latent distribution colored using the ground truth shear of each image
im = ax[1].scatter(z_mean4[:,-1], z_mean4[:,-2], c=shears_all4[:,0], s=1, cmap='jet')
ax[1].set_xlabel("$z_1$", fontsize=14)
ax[1].set_ylabel("$z_2$", fontsize=14)
cbar = fig.colorbar(im, ax=ax[1], shrink=.8)
cbar.set_label("Shear", fontsize=14)
cbar.ax.tick_params(labelsize=10)

plt.show()

# %%
# Finally the plot of encoded angle vs. ground truth rotation applied to the images.
# The points are colored using the suit of the images.

fig, ax = plt.subplots(figsize = (5,5), linewidth = 500)
ax.scatter(torch.deg2rad(angles_all4), z_mean4[:,0], c = labels_all4, s =5, cmap = 'jet')
ax.set_xlabel("ground truth", fontsize=14)
ax.set_ylabel("angular encoding", fontsize=14)
# Out:
# Text(0, 0.5, 'angular encoding')
