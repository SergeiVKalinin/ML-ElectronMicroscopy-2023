# %% [markdown]
# # <center> <font color = "green">A processing and analytics system for microscopy data workflows: the Pycroscopy ecosystem of packages
# <img src = "https://github.com/pycroscopy/pycroscopy/blob/main/docs/px_logo_new.png?raw=true"> </img>
#
# <center><font size = 3> R. Vasudevan<sup>1</sup>, S. M. Valleti,<sup>2</sup> M. Ziatdinov,<sup>1,3</sup> G. Duscher,<sup>4,</sup> and S. Somnath<sup>5,6</sup> </font></center>
#
# <sup>1</sup>Center for Nanophase Materials Sciences, Oak Ridge National Laboratory \
# <sup>2</sup>Bredesen Center for Interdisciplinary Research, University of Tennessee, Knoxville \
# <sup>3</sup>Computational Sciences and Engineering Division, Oak Ridge National Laboratory \
# <sup>4</sup>Department of Materials Science and Engineering, University of Tennessee, Knoxville \
# <sup>5</sup>National Center for Computational Sciences, Oak Ridge National Laboratory \
# <sup>6</sup>Current affiliation: McKinsey Consulting Group
#
# This notebook accompanies our paper on the Pycroscopy Ecosystem of packages.
#
# We will go through several examples of use cases. More information can be found <a href = "https://pycroscopy.github.io/pycroscopy/ecosystem.html">here</a>
#
# ## <left> Visualization, Spectral processing and Matrix Factorization with Pycroscopy
#
# In this notebook we will go thorugh basics of loading files, visualizing them, fitting spectra to functions, and then more advanced image manipulation and matrix factorization

# %%
#Load required packages
# !pip install pyNSID SciFiReaders nanonispy gwyfile pycroscopy wget ipympl sidpy
# Out:
# Collecting pyNSID
#   Downloading pyNSID-0.0.7-py2.py3-none-any.whl (12 kB)
# Collecting SciFiReaders
#   Downloading SciFiReaders-0.0.9-py2.py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 kB 4.3 MB/s eta 0:00:00
# Collecting nanonispy
#   Downloading nanonispy-1.1.0-py3-none-any.whl (10 kB)
# Collecting gwyfile
#   Downloading gwyfile-0.2.0-py2.py3-none-any.whl (8.9 kB)
# Collecting pycroscopy
#   Downloading pycroscopy-0.63.0-py2.py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 6.3 MB/s eta 0:00:00
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ipympl
#   Downloading ipympl-0.9.3-py2.py3-none-any.whl (511 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.6/511.6 kB 39.0 MB/s eta 0:00:00
# Collecting sidpy
#   Downloading sidpy-0.12.0-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.0/99.0 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.10/dist-packages (from pyNSID) (1.22.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from pyNSID) (0.12.0)
# Collecting cytoolz (from pyNSID)
#   Downloading cytoolz-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 59.6 MB/s eta 0:00:00
# Requirement already satisfied: dask>=0.10 in /usr/local/lib/python3.10/dist-packages (from pyNSID) (2022.12.1)
# Requirement already satisfied: h5py>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from pyNSID) (3.8.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from pyNSID) (1.16.0)
# Collecting ase (from pyNSID)
#   Downloading ase-3.22.1-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 44.3 MB/s eta 0:00:00
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from SciFiReaders) (0.56.4)
# Collecting ipython==7.1.0 (from SciFiReaders)
#   Downloading ipython-7.1.0-py3-none-any.whl (764 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 764.0/764.0 kB 46.4 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython==7.1.0->SciFiReaders) (67.7.2)
# Collecting jedi>=0.10 (from ipython==7.1.0->SciFiReaders)
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 46.9 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython==7.1.0->SciFiReaders) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython==7.1.0->SciFiReaders) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython==7.1.0->SciFiReaders) (5.7.1)
# Collecting prompt-toolkit<2.1.0,>=2.0.0 (from ipython==7.1.0->SciFiReaders)
#   Downloading prompt_toolkit-2.0.10-py3-none-any.whl (340 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.0/340.0 kB 27.9 MB/s eta 0:00:00
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython==7.1.0->SciFiReaders) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython==7.1.0->SciFiReaders) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.10/dist-packages (from ipython==7.1.0->SciFiReaders) (4.8.0)
# Requirement already satisfied: scipy>=0.17.1 in /usr/local/lib/python3.10/dist-packages (from pycroscopy) (1.10.1)
# Requirement already satisfied: scikit-image>=0.12.3 in /usr/local/lib/python3.10/dist-packages (from pycroscopy) (0.19.3)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.10/dist-packages (from pycroscopy) (1.2.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pycroscopy) (3.7.1)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pycroscopy) (2.0.1+cu118)
# Collecting tensorly>=0.6.0 (from pycroscopy)
#   Downloading tensorly-0.8.1-py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.7/229.7 kB 23.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pycroscopy) (4.65.0)
# Requirement already satisfied: ipywidgets>=5.2.2 in /usr/local/lib/python3.10/dist-packages (from pycroscopy) (7.7.1)
# Collecting simpleitk (from pycroscopy)
#   Downloading SimpleITK-2.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 MB 10.8 MB/s eta 0:00:00
# Collecting pysptools (from pycroscopy)
#   Downloading pysptools-0.15.0.tar.gz (8.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 54.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cvxopt>=1.2.7 in /usr/local/lib/python3.10/dist-packages (from pycroscopy) (1.3.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipympl) (0.2.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from ipympl) (8.4.0)
# Requirement already satisfied: distributed>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sidpy) (2022.12.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from sidpy) (5.9.5)
# Requirement already satisfied: joblib>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from sidpy) (1.2.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from sidpy) (5.5.6)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask>=0.10->pyNSID) (8.1.3)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from dask>=0.10->pyNSID) (2.2.1)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from dask>=0.10->pyNSID) (2023.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask>=0.10->pyNSID) (23.1)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask>=0.10->pyNSID) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask>=0.10->pyNSID) (6.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.0.0->sidpy) (3.1.2)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.0.0->sidpy) (1.0.0)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.0.0->sidpy) (1.0.5)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.0.0->sidpy) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.0.0->sidpy) (2.0.0)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.0.0->sidpy) (6.3.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.0.0->sidpy) (1.26.16)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2.0.0->sidpy) (3.0.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=5.2.2->pycroscopy) (3.6.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=5.2.2->pycroscopy) (3.0.7)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->sidpy) (6.1.12)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pycroscopy) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pycroscopy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pycroscopy) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pycroscopy) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pycroscopy) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->pycroscopy) (2.8.2)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12.3->pycroscopy) (3.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12.3->pycroscopy) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12.3->pycroscopy) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12.3->pycroscopy) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.17.1->pycroscopy) (3.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->pycroscopy) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->pycroscopy) (4.6.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->pycroscopy) (1.11.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->pycroscopy) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.0->pycroscopy) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.0->pycroscopy) (16.0.6)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->SciFiReaders) (0.39.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.10->ipython==7.1.0->SciFiReaders) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython==7.1.0->SciFiReaders) (0.2.6)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (6.4.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->distributed>=2.0.0->sidpy) (2.1.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel->sidpy) (5.3.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel->sidpy) (23.2.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect->ipython==7.1.0->SciFiReaders) (0.7.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.0->pycroscopy) (1.3.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->sidpy) (3.7.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (21.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (5.9.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (0.17.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (21.2.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=5.2.2->pycroscopy) (2.21)
# WARNING: The candidate selected for download or install is a yanked version: 'ipython' candidate (version 7.1.0 at https://files.pythonhosted.org/packages/ea/56/d75d25b30936bff3f6b4d7b80cfd399b703e2162f31afee926f66ff77b13/ipython-7.1.0-py3-none-any.whl (from https://pypi.org/simple/ipython/) (requires-python:>=3.5))
# Reason for being yanked: <none given>
# Building wheels for collected packages: wget, pysptools
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=07fb4b30f6c8a7c5aa070222228b29ca80d692671026c7b63bcd81d19a3e63da
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
#   Building wheel for pysptools (setup.py) ... done
#   Created wheel for pysptools: filename=pysptools-0.15.0-py3-none-any.whl size=8133732 sha256=64cab96f2918be491e65ebb5941acfeca9e5648f497bb4dd96c0777b6446f66c
#   Stored in directory: /root/.cache/pip/wheels/ea/08/3b/c045ea3722a5fef1f8698f060a17b59140235fef580fe4f1b5
# Successfully built wget pysptools
# Installing collected packages: wget, simpleitk, pysptools, prompt-toolkit, nanonispy, jedi, gwyfile, cytoolz, tensorly, ipython, ase, sidpy, ipympl, SciFiReaders, pyNSID, pycroscopy
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.38
#     Uninstalling prompt-toolkit-3.0.38:
#       Successfully uninstalled prompt-toolkit-3.0.38
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 7.1.0 which is incompatible.
# Successfully installed SciFiReaders-0.0.9 ase-3.22.1 cytoolz-0.12.1 gwyfile-0.2.0 ipympl-0.9.3 ipython-7.1.0 jedi-0.18.2 nanonispy-1.1.0 prompt-toolkit-2.0.10 pyNSID-0.0.7 pycroscopy-0.63.0 pysptools-0.15.0 sidpy-0.12.0 simpleitk-2.2.1 tensorly-0.8.1 wget-3.2

# %%
#download the required data
import wget
wget.download(url='https://github.com/pycroscopy/pycroscopy/blob/main/sample_data/bfo_iv_final.hf5?raw=true',
              out = 'bfo_iv_final.hf5');
wget.download(url='https://github.com/pycroscopy/pycroscopy/blob/main/sample_data/bto_atomic.dm3?raw=true',
              out = 'bto_atomic.dm3');
wget.download(url='https://github.com/pycroscopy/pycroscopy/blob/main/sample_data/re48.tiff?raw=true',
              out = 're48.tiff');

# %%
#Check if in Google colab or not
import sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    # %matplotlib widget
    from google.colab import output
    output.enable_custom_widget_manager()
else:
    # %matplotlib notebook

# %%
import sys
import os
import matplotlib.pyplot as plt
import numpy as np

import pyNSID
import sidpy as sid
import SciFiReaders as sr
from sidpy.proc.fitter import SidFitter
# Out:
# You don't have igor installed.     If you wish to open igor files, you will need to install it     (pip install igor) before attempting.

# %% [markdown]
# # Load and Visualize Spectral dataset
#
# Here we load a dataset of I-V curves captured by conductive atomic force microscopy, on a BiFeO3 sample.
# The data has been transformed so that we plot not the log of the current density J, as a function of the square root of the electric field. I-V curves plotted in this fashion will be linear if they follow Schottky emission cinduction laws. The dataset was originally presented in the paper <a href = "https://www.nature.com/articles/s41467-017-01334-5"> Vasudevan et al. Nat Commun. 8, 1318 (2017) </a>
#
# Here we will load the file, which was saved as a pyNSID HDF5 file, using SciFiReaders, which reads it into a <i>sidpy.Dataset</i> object
#
# Then we will use the .plot() method of the <i>sidpy.Dataset</i> object for interactive visualization.

# %%
data_path = r'bfo_iv_final.hf5'
dr = sr.NSIDReader(data_path)
dataset_sid = dr.read()[0]
dataset_sid.plot();
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Functional Fitting
#
# Much of the data appears linear. We can define any function of our choice and use sidpy's <i>SidFitter</i> class to make it easy to perform the fit on all of the spectra. We simply define the fit function, instantiate the class, and then call the do_fit() method.
#
# Advantages of using the fitter class include:
# - Innate scalability: we leverage the parallelism of Dask, so that the computations are performed in parallel
# - Superior priors: We can use a k-means cluster approach to improve priors for the function fits, as described in <a href = "https://iopscience.iop.org/article/10.1088/2632-2153/abfbba/meta">Creange et al.</a>
# - Dimension handling: There is intelligent folding and unfolding within the class to handle simple cases. For more complex situations (e.g., when there are multiple spectral dimensions, but only one is used for the fitting), these can be specified too.

# %%
#Define the function we want each spectrum to

def one_lin_func(xvec, *coeff):
    a1,a2 = coeff
    return a1*xvec + a2

#Instantiate the SidFitter class
fitter = SidFitter(dataset_sid, one_lin_func,num_workers=4,
                           threads=2, return_cov=False, return_fit=True, return_std=False,
                           km_guess=True,num_fit_parms = 2)
# Out:
# INFO:distributed.http.proxy:To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# INFO:distributed.scheduler:State start
# INFO:distributed.scheduler:  Scheduler at:     tcp://127.0.0.1:41115
# INFO:distributed.scheduler:  dashboard at:            127.0.0.1:8787
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:46107'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:36203'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:36809'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:38277'
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:34803', name: 2, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:34803
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:53950
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:36679', name: 1, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:36679
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:53956
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:38201', name: 3, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:38201
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:53970
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:34679', name: 0, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:34679
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:53978
# INFO:distributed.scheduler:Receive client connection: Client-8edeb652-19e4-11ee-8741-0242ac1c000c
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:53986

# %%
fit_parameters, fitted_dataset = fitter.do_fit() #With one line we can fit all the spectra
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:46107'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:36203'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:36809'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:38277'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:53978; closing.
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:53956; closing.
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:53950; closing.
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:53970; closing.
# INFO:distributed.scheduler:Remove worker <WorkerState 'tcp://127.0.0.1:34679', name: 0, status: closing, memory: 0, processing: 0>
# INFO:distributed.core:Removing comms to tcp://127.0.0.1:34679
# INFO:distributed.scheduler:Remove worker <WorkerState 'tcp://127.0.0.1:36679', name: 1, status: closing, memory: 0, processing: 0>
# INFO:distributed.core:Removing comms to tcp://127.0.0.1:36679
# INFO:distributed.scheduler:Remove worker <WorkerState 'tcp://127.0.0.1:34803', name: 2, status: closing, memory: 0, processing: 0>
# INFO:distributed.core:Removing comms to tcp://127.0.0.1:34803
# INFO:distributed.scheduler:Remove worker <WorkerState 'tcp://127.0.0.1:38201', name: 3, status: closing, memory: 0, processing: 0>
# INFO:distributed.core:Removing comms to tcp://127.0.0.1:38201
# INFO:distributed.scheduler:Lost all workers
# INFO:distributed.scheduler:Scheduler closing...
# INFO:distributed.scheduler:Scheduler closing all comms

# %% [markdown]
# ## Visualize Fit Results
#
# We can visualize the parameter maps from the fititng, or visualize the fitted data curves

# %% [markdown]
# ### Visualize coeffient maps
#
# The functional fits provided us with coefficient maps for the fit parameters.
#
# We can simply call the .plot() method again to visualize them.

# %%
fit_parameters.plot();
# Out:
# HBox(children=(Play(value=0, description='Press play', interval=500, max=2), IntSlider(value=0, continuous_upd…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Visualize fitted spectra
# Each spectrum is associated with a specific fit.
#
# We can visualize them again easily
# through calling the <i>visualize_fit_results()</i> method of the SidFitter class.

# %%
fitter.visualize_fit_results() # We can visualize the results of the fit interactively too...
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Save the results
#
# We can easily save back to the original HDF5 file.
# This will help us when it comes to e.g., publications -> provide all the necessary data.

# %%
import h5py
new_h5_filename = r'new_exp_file2.hf5'
hf = h5py.File(new_h5_filename, 'a') #Create a new file

# %%
#We can save the fitted results with pyNSID
hf_grp = hf.create_group('Measurement_000/Channel_000') #Create a group

#Let's save the raw data first
pyNSID.hdf_io.write_nsid_dataset(dataset_sid, hf_grp, main_data_name="IV_BFO_Raw")
# Out:
# /usr/local/lib/python3.10/dist-packages/pyNSID/io/hdf_utils.py:376: FutureWarning: validate_h5_dimension may be removed in a future version
#   warn('validate_h5_dimension may be removed in a future version',
# <HDF5 dataset "IV_BFO_Raw": shape (50, 50, 53), type "<f8">

# %%
fitted_dataset.metadata
# Out:
# {'fit_parms_dict': {'fit_parameters_labels': None,
#   'fitting_function': 'def one_lin_func(xvec, *coeff):\n    a1,a2 = coeff\n    return a1*xvec + a2\n',
#   'guess_function': 'Not Provided',
#   'ind_dims': (0, 1)}}

# %%
sid.hdf_utils.print_tree(hf)
# Out:
# /
# ├ Measurement_000
#   ---------------
#   ├ Channel_000
#     -----------
#     ├ IV_BFO_Raw
#       ----------
#       ├ $\sqrt E$
#       ├ IV_BFO_Raw
#       ├ x
#       ├ y

# %%
hf_results_grp = hf['Measurement_000/Channel_000/IV_BFO_Raw'] #Let's put the results here.

pyNSID.hdf_io.write_nsid_dataset(fit_parameters, hf_results_grp, main_data_name="IV_BFO_Fit_Parameters")
pyNSID.hdf_io.write_nsid_dataset(fitted_dataset, hf_results_grp, main_data_name="IV_BFO_Fitted_Spectra")

sid.hdf_utils.print_tree(hf) #print result

hf.close()
# Out:
# /
# ├ Measurement_000
#   ---------------
#   ├ Channel_000
#     -----------
#     ├ IV_BFO_Raw
#       ----------
#       ├ $\sqrt E$
#       ├ IV_BFO_Fit_Parameters
#         ---------------------
#         ├ IV_BFO_Fit_Parameters
#         ├ fit_parms
#         ├ metadata
#           --------
#           ├ fit_parms_dict
#             --------------
#         ├ x
#         ├ y
#       ├ IV_BFO_Fitted_Spectra
#         ---------------------
#         ├ $\sqrt E$
#         ├ IV_BFO_Fitted_Spectra
#         ├ metadata
#           --------
#           ├ fit_parms_dict
#             --------------
#         ├ x
#         ├ y
#       ├ IV_BFO_Raw
#       ├ x
#       ├ y
# /usr/local/lib/python3.10/dist-packages/pyNSID/io/hdf_utils.py:376: FutureWarning: validate_h5_dimension may be removed in a future version
#   warn('validate_h5_dimension may be removed in a future version',
# /usr/local/lib/python3.10/dist-packages/pyNSID/io/hdf_utils.py:376: FutureWarning: validate_h5_dimension may be removed in a future version
#   warn('validate_h5_dimension may be removed in a future version',

# %% [markdown]
# # Second example - Image analysis
#
# The pycroscopy package has some tools for generic image analysis, as well as wrappers around common machine learning methods. These include matrix and tensor factorization techniques. Let us explore one example.
#
# First we will import a microscopy image, and then we will perform image windowing
#
# We will then use matrix factorization to analyze the spatial distribution of different phases
#
# This is explained in <a href = "https://pubs.acs.org/doi/full/10.1021/acs.nanolett.6b02130">this article</a>.

# %%
# %matplotlib notebook
# Out:
# Warning: Cannot change to a different GUI toolkit: notebook. Using widget instead.

# %%
import sys
import os
import matplotlib.pyplot as plt
import numpy as np
import pyNSID

import sidpy as sid
import SciFiReaders as sr
from sidpy.proc.fitter import SidFitter
import warnings
warnings.filterwarnings('ignore')

# %%
dm3_file = r'bto_atomic.dm3'
png_file = r're48.tiff'

dm3_reader = sr.DM3Reader(dm3_file)
img_reader = sr.ImageReader(png_file)

data = dm3_reader.read()[0]

# %%
data.plot();
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Let's crop it to only the film part
data_cropped = data[200:-200,10:548]

# %%
data_cropped.plot();
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#Let's do some image windowing
from pycroscopy.image import ImageWindowing

parms_dict = {}
parms_dict['window_step_x'] = 8
parms_dict['window_step_y'] = 8
parms_dict['window_size_x'] = 64
parms_dict['window_size_y'] = 64
parms_dict['mode'] = 'fft'
parms_dict['filter'] = 'hamming'
parms_dict['zoom_factor'] = 2
parms_dict['interpol_factor'] = 2
iw = ImageWindowing(parms_dict)
windows = iw.MakeWindows(data_cropped)
windows = np.abs(np.log(np.abs(windows)))

# %%
windows.plot();
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from pycroscopy.learn.ml.matrix_factor import MatrixFactor
mfactor = MatrixFactor(np.abs(windows), method = 'nmf',n_components = 2 )
output = mfactor.do_fit()

# %%
abundances = output[0]
components = output[1]
abund = np.array(abundances)
comps = np.array(components)

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, axes = plt.subplots(nrows=1, ncols=mfactor.ncomp, figsize = (10,3))
for ind, ax in enumerate(axes.flat):
    im1 = ax.imshow(comps[ind,:,:])
    ax.set_title('Component #' + str(ind))
    divider = make_axes_locatable(ax)
    cax = divider.append_axes('right', size='5%', pad=0.05)
    fig.colorbar(im1, cax=cax, orientation='vertical')
    ax.axis('off')
fig.tight_layout()

fig, axes = plt.subplots(nrows=1, ncols=mfactor.ncomp, figsize = (10,3))
for ind, ax in enumerate(axes.flat):
    im1 = ax.imshow(abund[:,:,ind])
    divider = make_axes_locatable(ax)
    cax = divider.append_axes('right', size='5%', pad=0.05)
    fig.colorbar(im1, cax=cax, orientation='vertical')
    ax.axis('off')

fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
